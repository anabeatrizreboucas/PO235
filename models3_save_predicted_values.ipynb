# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import glob

from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import make_scorer, mean_squared_error
from math import sqrt


import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")

# %%
# Definir random state e métrica
seed = 1
def rmse(y_true, y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

scorer = make_scorer(rmse, greater_is_better=False)
cv = TimeSeriesSplit(n_splits=5)

# %%
# Novo conjunto de algoritmos
algorithms = {
    'Decision Tree': GridSearchCV(
        Pipeline([('scaler', RobustScaler()), ('tree', DecisionTreeRegressor(random_state=seed))]),
        param_grid={
            'tree__max_depth': [10, 20, 30],
            'tree__criterion': ['squared_error', 'friedman_mse'],
        },
        scoring=scorer,
        cv=cv,
    ),
    'KNN': GridSearchCV(
        Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsRegressor())]),
        param_grid={
            'knn__n_neighbors': [3, 5, 7],
            'knn__weights': ['uniform', 'distance'],
        },
        scoring=scorer,
        cv=cv,
    ),    
    'MLP': GridSearchCV(
        Pipeline([('scaler', StandardScaler()), ('mlp', MLPRegressor(random_state=seed, max_iter=500))]),
        param_grid={
            'mlp__hidden_layer_sizes': [(50,), (100,), (50, 50)],
            'mlp__activation': ['relu', 'tanh', 'logistic'],
        },
        scoring=scorer,
        cv=cv,
    ),
    'Random Forest': GridSearchCV(
        Pipeline([
            ('scaler', StandardScaler()),
            ('rf', RandomForestRegressor(random_state=seed))]),
        param_grid={
            'rf__n_estimators': [50, 100],
            'rf__max_depth': [10, 20],
        },
        scoring=scorer,
        cv=cv,
    ),
    'AdaBoost': GridSearchCV(
        Pipeline([('scaler', StandardScaler()), ('ada', AdaBoostRegressor(random_state=seed))]),
        param_grid={
            'ada__n_estimators': [50, 100, 200],
            'ada__learning_rate': [0.01, 0.1, 1],
        },
        scoring=scorer,
        cv=cv,
    ), 
    'Gradient Boosting': GridSearchCV(
        Pipeline([('scaler', StandardScaler()), ('gb', GradientBoostingRegressor(random_state=seed))]),
        param_grid={
            'gb__n_estimators': [50, 100, 200],
            'gb__learning_rate': [0.01, 0.1, 0.2],
            'gb__max_depth': [3, 5, 7],
        },
        scoring=scorer,
        cv=cv,
    )

}

# %%
# Use a wildcard pattern to match any CSV file in the yahoo_data subfolder
file_path_pattern = 'yahoo_data/yahoo_data*.csv'

# Find all files matching the pattern
file_list = glob.glob(file_path_pattern)

# Check if any files matched
if file_list:
    # Get the first matching file (if there are multiple)
    file_path = file_list[-1]
    
    # Read the CSV file
    data = pd.read_csv(file_path)
    
    # Display the first few rows of the data
    print(data.head(),'\n\n',data.tail())

else:
    print("No files found matching the pattern.")
# Out:
#    stock        date   Open   High    Low  Close    Volume   Adjusted
# 0  ABEV3  2022-01-03  15.42  15.54  15.15  15.33  23833600  13.839315
# 1  ABEV3  2022-01-04  15.32  15.40  15.04  15.31  16357700  13.821261
# 2  ABEV3  2022-01-05  15.25  15.29  14.96  15.01  24652000  13.550432
# 3  ABEV3  2022-01-06  15.04  15.06  14.66  14.77  20406300  13.333770
# 4  ABEV3  2022-01-07  14.80  14.80  14.45  14.53  19673600  13.117107
#
#         stock        date  Open  High   Low  Close  Volume  Adjusted
# 54435  WIZC3  2024-11-12  5.85  5.87  5.70   5.77  468800      5.77
# 54436  WIZC3  2024-11-13  5.80  5.80  5.66   5.77  525300      5.77
# 54437  WIZC3  2024-11-14  5.77  5.85  5.71   5.79  411300      5.79
# 54438  WIZC3  2024-11-18  5.80  5.89  5.75   5.89  563300      5.89
# 54439  WIZC3  2024-11-19  5.89  5.99  5.84   5.91  398600      5.91

# %%
days = 5

# %%
data = data.drop(columns=['Open', 'High', 'Low', 'Close'])
data['Future'] = data['Adjusted'].shift(-days)
data = data.dropna()

print(data.head(),'\n\n',data.tail())

tickers = data['stock'].unique()
print(tickers)
# Out:
#    stock        date    Volume   Adjusted     Future
# 0  ABEV3  2022-01-03  23833600  13.839315  13.225439
# 1  ABEV3  2022-01-04  16357700  13.821261  13.252522
# 2  ABEV3  2022-01-05  24652000  13.550432  13.433074
# 3  ABEV3  2022-01-06  20406300  13.333770  13.532376
# 4  ABEV3  2022-01-07  19673600  13.117107  13.631681
#
#         stock        date  Volume  Adjusted  Future
# 54430  WIZC3  2024-11-05  295400      5.85    5.77
# 54431  WIZC3  2024-11-06  331600      5.89    5.77
# 54432  WIZC3  2024-11-07  406800      5.85    5.79
# 54433  WIZC3  2024-11-08  947500      5.84    5.89
# 54434  WIZC3  2024-11-11  346600      5.85    5.91
# ['ABEV3' 'AGRO3' 'ALOS3' 'AMER3' 'ARML3' 'AURE3' 'B3SA3' 'BLAU3' 'CMIG3'
#  'CMIG4' 'CPFE3' 'CPLE3' 'CPLE6' 'CSAN3' 'CSMG3' 'CURY3' 'CYRE3' 'DIRR3'
#  'ELET3' 'ELET6' 'ELMD3' 'ENEV3' 'ENGI11' 'EVEN3' 'EZTC3' 'FESA4' 'FIQE3'
#  'GFSA3' 'GRND3' 'HBRE3' 'HYPE3' 'IGTI11' 'INTB3' 'ITSA3' 'ITSA4' 'JHSF3'
#  'KEPL3' 'LAVV3' 'LEVE3' 'LOGG3' 'MDNE3' 'MELK3' 'MILS3' 'MULT3' 'ODPV3'
#  'ORVR3' 'PETR3' 'PETR4' 'PLPL3' 'POMO3' 'POMO4' 'PRIO3' 'RECV3' 'ROMI3'
#  'SAPR11' 'SAPR4' 'SBSP3' 'SHUL4' 'SMFT3' 'SMTO3' 'SOJA3' 'STBP3' 'SYNE3'
#  'TAEE11' 'TAEE4' 'TFCO4' 'TGMA3' 'TOTS3' 'TRIS3' 'TRPL4' 'VALE3' 'VIVA3'
#  'VLID3' 'VULC3' 'WEGE3' 'WIZC3']

# %%
# Dictionary to store train and test sets for each ticker
ticker_train_test_data = {}

# Df to store predictions
predictions = pd.DataFrame(columns=['date', 'stock', 'Adjusted', 'Prediction', 'Model'])
predictions
# Out:
# Empty DataFrame
# Columns: [date, stock, Adjusted, Prediction, Model]
# Index: []

# %%
# Define the test period (last 30 rows)
test_rows = 30
results = []
for ticker in data['stock'].unique():
    ticker_data = data[data['stock'] == ticker]
    print(ticker)

    # Check if there are enough rows for a 30-row test set
    if len(ticker_data) > test_rows:
        # Split into train and test
        train_data = ticker_data.iloc[:-test_rows]
        test_data = ticker_data.iloc[-test_rows:]
    else:
        # If not enough data, use all data for training and leave test empty
        train_data = ticker_data
        test_data = pd.DataFrame()  # Empty DataFrame for test set
        print("There is NO data enough for train and test")
    
    # Store train and test sets in the dictionary
    ticker_train_test_data[ticker] = {
        'train': train_data,
        'test': test_data
    }

    print(train_data.head())

    # Executar cross-validation e coletar as melhores métricas
    results_ticker = []

    for name, model in algorithms.items():
        model.fit(train_data[['Adjusted', 'Volume']], train_data['Future'])
        y_pred = model.predict(test_data[['Adjusted', 'Volume']])
        rmse_value = rmse(test_data['Future'], y_pred)
        results_ticker.append((name, rmse_value, ticker))
        
        #save predictions
        predictions = pd.concat([predictions, pd.DataFrame({'stock': ticker, 'date': test_data['date'], 'Adjusted': test_data['Adjusted'] , 'Prediction': y_pred, 'Model': name})])
        print(predictions.tail())
    
    #print(test_data.head())
    results_ticker = pd.DataFrame(results_ticker, columns=['Algorithm', 'RMSE', 'Ticker'])
    print(results_ticker)

    results.append(results_ticker)
# Out:
# ABEV3
#    stock        date    Volume   Adjusted     Future
# 0  ABEV3  2022-01-03  23833600  13.839315  13.225439
# 1  ABEV3  2022-01-04  16357700  13.821261  13.252522
# 2  ABEV3  2022-01-05  24652000  13.550432  13.433074
# 3  ABEV3  2022-01-06  20406300  13.333770  13.532376
# 4  ABEV3  2022-01-07  19673600  13.117107  13.631681
#            date  stock  Adjusted  Prediction          Model
# 718  2024-11-12  ABEV3     12.58   12.428966  Decision Tree
# 719  2024-11-13  ABEV3     12.73   12.842442  Decision Tree
# 720  2024-11-14  ABEV3     12.64   13.295069  Decision Tree
# 721  2024-11-18  ABEV3     12.42   12.416639  Decision Tree
# 722  2024-11-19  ABEV3     12.43   12.819196  Decision Tree
# C:\Users\PICHAU\AppData\Local\Temp\ipykernel_16348\3886593348.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   predictions = pd.concat([predictions, pd.DataFrame({'stock': ticker, 'date': test_data['date'], 'Adjusted': test_data['Adjusted'] , 'Prediction': y_pred, 'Model': name})])
#            date  stock  Adjusted  Prediction Model
# 718  2024-11-12  ABEV3     12.58   12.410465   KNN
# 719  2024-11-13  ABEV3     12.73   12.795246   KNN
# 720  2024-11-14  ABEV3     12.64   12.526181   KNN
# 721  2024-11-18  ABEV3     12.42   12.425765   KNN
# 722  2024-11-19  ABEV3     12.43   12.509098   KNN
#            date  stock  Adjusted  Prediction Model
# 718  2024-11-12  ABEV3     12.58   12.630307   MLP
# 719  2024-11-13  ABEV3     12.73   12.759354   MLP
# 720  2024-11-14  ABEV3     12.64   12.664443   MLP
# 721  2024-11-18  ABEV3     12.42   12.467499   MLP
# 722  2024-11-19  ABEV3     12.43   12.492000   MLP
#            date  stock  Adjusted  Prediction          Model
# 718  2024-11-12  ABEV3     12.58   12.451218  Random Forest
# 719  2024-11-13  ABEV3     12.73   12.806292  Random Forest
# 720  2024-11-14  ABEV3     12.64   12.903756  Random Forest
# 721  2024-11-18  ABEV3     12.42   12.555392  Random Forest
# 1717  2024-11-18  ALOS3  21.563848   21.985514  AdaBoost
# 1718  2024-11-19  ALOS3  21.680000   21.860618  AdaBoost
#             date  stock   Adjusted  Prediction              Model
# 1714  2024-11-12  ALOS3  21.504116   21.936007  Gradient Boosting
# 1715  2024-11-13  ALOS3  21.743050   21.320292  Gradient Boosting
# 1716  2024-11-14  ALOS3  21.852562   21.970640  Gradient Boosting
# 1717  2024-11-18  ALOS3  21.563848   22.007434  Gradient Boosting
# 1718  2024-11-19  ALOS3  21.680000   22.002698  Gradient Boosting
#            Algorithm         RMSE Ticker
# 0      Decision Tree  1158.702838  ALOS3
# 1                KNN  1158.650746  ALOS3
# 2                MLP  1158.462376  ALOS3
# 3      Random Forest  1158.651560  ALOS3
# 4           AdaBoost  1158.643244  ALOS3
# 5  Gradient Boosting  1158.631585  ALOS3
# AMER3
#       stock        date  Volume     Adjusted       Future
# 1719  AMER3  2022-01-03   76374  3024.269775  2645.992188
# 1720  AMER3  2022-01-04   54433  2920.925781  2734.711914
# 1721  AMER3  2022-01-05   54533  2790.283691  2874.128662
# 1722  AMER3  2022-01-06   47716  2852.679932  2884.853027
# 1723  AMER3  2022-01-07   78632  2700.589111  2955.048828
#             date  stock  Adjusted  Prediction          Model
# 2437  2024-11-12  AMER3      3.34    4.040000  Decision Tree
# 2438  2024-11-13  AMER3      3.36    4.040000  Decision Tree
# 2439  2024-11-14  AMER3      9.41    6.740000  Decision Tree
# 2440  2024-11-18  AMER3      9.52    6.740000  Decision Tree
# 2441  2024-11-19  AMER3      9.10    6.556667  Decision Tree
#             date  stock  Adjusted  Prediction Model
# 2437  2024-11-12  AMER3      3.34    6.611632   KNN
# 2438  2024-11-13  AMER3      3.36    6.685476   KNN
# 2439  2024-11-14  AMER3      9.41    6.656173   KNN
# 2440  2024-11-18  AMER3      9.52    6.619198   KNN
# 2441  2024-11-19  AMER3      9.10    6.582872   KNN
#             date  stock  Adjusted  Prediction Model
# 2437  2024-11-12  AMER3      3.34   11.648521   MLP
# 2438  2024-11-13  AMER3      3.36   11.719830   MLP
# 2439  2024-11-14  AMER3      9.41   12.238330   MLP
# 2440  2024-11-18  AMER3      9.52   11.984988   MLP
# 2441  2024-11-19  AMER3      9.10   11.256526   MLP
#             date  stock  Adjusted  Prediction          Model
# 2437  2024-11-12  AMER3      3.34    4.504919  Random Forest
# 2438  2024-11-13  AMER3      3.36    4.509419  Random Forest
# 2439  2024-11-14  AMER3      9.41    6.548813  Random Forest
# 2440  2024-11-18  AMER3      9.52    6.254442  Random Forest
# 2441  2024-11-19  AMER3      9.10    6.493127  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 2437  2024-11-12  AMER3      3.34   39.421871  AdaBoost
# 2438  2024-11-13  AMER3      3.36   39.421871  AdaBoost
# 2439  2024-11-14  AMER3      9.41   39.421871  AdaBoost
# 2440  2024-11-18  AMER3      9.52   39.421871  AdaBoost
# 2441  2024-11-19  AMER3      9.10   39.421871  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 2437  2024-11-12  AMER3      3.34    4.555473  Gradient Boosting
# 2438  2024-11-13  AMER3      3.36    4.555473  Gradient Boosting
# 2439  2024-11-14  AMER3      9.41    6.675699  Gradient Boosting
# 2440  2024-11-18  AMER3      9.52    6.601179  Gradient Boosting
# 2441  2024-11-19  AMER3      9.10    6.675699  Gradient Boosting
#            Algorithm       RMSE Ticker
# 0      Decision Tree  11.828714  AMER3
# 1                KNN  27.261078  AMER3
# 2                MLP  31.037031  AMER3
# 3      Random Forest   9.926028  AMER3
# 4           AdaBoost  33.029173  AMER3
# 5  Gradient Boosting  10.084550  AMER3
# ARML3
#       stock        date  Volume   Adjusted     Future
# 2442  ARML3  2022-01-03  757700  22.414196  18.365902
# 2443  ARML3  2022-01-04  746000  21.216421  18.430895
# 2444  ARML3  2022-01-05  637000  19.572958  20.157921
# 2445  ARML3  2022-01-06  907800  18.950857  19.953650
# 2446  ARML3  2022-01-07  664600  18.941574  20.501471
#             date  stock  Adjusted  Prediction          Model
# 3160  2024-11-12  ARML3      7.34    8.350000  Decision Tree
# 3161  2024-11-13  ARML3      7.60    8.350000  Decision Tree
# 3162  2024-11-14  ARML3      7.95    8.134888  Decision Tree
# 3163  2024-11-18  ARML3      8.14    8.120000  Decision Tree
# 3164  2024-11-19  ARML3      8.24    8.304185  Decision Tree
#             date  stock  Adjusted  Prediction Model
# 3160  2024-11-12  ARML3      7.34    8.579687   KNN
# 3161  2024-11-13  ARML3      7.60    8.948371   KNN
# 3162  2024-11-14  ARML3      7.95    8.999330   KNN
# 3163  2024-11-18  ARML3      8.14    8.639100   KNN
# 3164  2024-11-19  ARML3      8.24    8.992937   KNN
#             date  stock  Adjusted  Prediction Model
# 3160  2024-11-12  ARML3      7.34    7.689163   MLP
# 3161  2024-11-13  ARML3      7.60    7.927410   MLP
# 3162  2024-11-14  ARML3      7.95    8.233608   MLP
# 3163  2024-11-18  ARML3      8.14    8.387792   MLP
# 3164  2024-11-19  ARML3      8.24    8.487055   MLP
#             date  stock  Adjusted  Prediction          Model
# 3160  2024-11-12  ARML3      7.34    8.120558  Random Forest
# 3161  2024-11-13  ARML3      7.60    8.223640  Random Forest
# 3162  2024-11-14  ARML3      7.95    8.131547  Random Forest
# 3163  2024-11-18  ARML3      8.14    8.298254  Random Forest
# 3164  2024-11-19  ARML3      8.24    8.483436  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 3160  2024-11-12  ARML3      7.34    8.744102  AdaBoost
# 3161  2024-11-13  ARML3      7.60    8.744102  AdaBoost
# 3162  2024-11-14  ARML3      7.95    8.744102  AdaBoost
# 3163  2024-11-18  ARML3      8.14    8.744102  AdaBoost
# 3164  2024-11-19  ARML3      8.24    8.744102  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 3160  2024-11-12  ARML3      7.34    8.442656  Gradient Boosting
# 3161  2024-11-13  ARML3      7.60    8.521591  Gradient Boosting
# 3162  2024-11-14  ARML3      7.95    8.550479  Gradient Boosting
# 3163  2024-11-18  ARML3      8.14    8.442656  Gradient Boosting
# 3164  2024-11-19  ARML3      8.24    8.670354  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  1.925003  ARML3
# 1                KNN  1.917945  ARML3
# 2                MLP  1.939526  ARML3
# 3      Random Forest  1.918503  ARML3
# 4           AdaBoost  1.904222  ARML3
# 5  Gradient Boosting  1.884709  ARML3
# AURE3
#       stock        date   Volume   Adjusted     Future
# 3165  AURE3  2022-03-28  5237900  12.855051  12.517999
# 3166  AURE3  2022-03-29  4714100  13.011821  12.251491
# 3167  AURE3  2022-03-30  4408600  12.478806  12.525837
# 3168  AURE3  2022-03-31  3876100  12.533675  12.541513
# 3169  AURE3  2022-04-01  4252000  12.612060  12.706120
#             date  stock  Adjusted  Prediction          Model
# 3825  2024-11-12  AURE3      9.96     10.7082  Decision Tree
# 3826  2024-11-13  AURE3      9.97     10.1500  Decision Tree
# 3827  2024-11-14  AURE3      9.98     10.0600  Decision Tree
# 3828  2024-11-18  AURE3      9.80     10.1500  Decision Tree
# 3829  2024-11-19  AURE3      9.89     10.4300  Decision Tree
#             date  stock  Adjusted  Prediction Model
# 3825  2024-11-12  AURE3      9.96   10.342369   KNN
# 3826  2024-11-13  AURE3      9.97   10.324387   KNN
# 3827  2024-11-14  AURE3      9.98   10.324387   KNN
# 3828  2024-11-18  AURE3      9.80   10.309743   KNN
# 3829  2024-11-19  AURE3      9.89   10.221429   KNN
#             date  stock  Adjusted  Prediction Model
# 3825  2024-11-12  AURE3      9.96   10.092196   MLP
# 3826  2024-11-13  AURE3      9.97   10.085270   MLP
# 3827  2024-11-14  AURE3      9.98   10.086292   MLP
# 3828  2024-11-18  AURE3      9.80    9.929919   MLP
# 3829  2024-11-19  AURE3      9.89   10.002028   MLP
#             date  stock  Adjusted  Prediction          Model
# 3825  2024-11-12  AURE3      9.96   10.520593  Random Forest
# 3826  2024-11-13  AURE3      9.97   10.304064  Random Forest
# 3827  2024-11-14  AURE3      9.98   10.281276  Random Forest
# 3828  2024-11-18  AURE3      9.80   10.295664  Random Forest
# 3829  2024-11-19  AURE3      9.89   10.356719  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 3825  2024-11-12  AURE3      9.96   10.479733  AdaBoost
# 3826  2024-11-13  AURE3      9.97   10.479733  AdaBoost
# 3827  2024-11-14  AURE3      9.98   10.479733  AdaBoost
# 3828  2024-11-18  AURE3      9.80   10.479733  AdaBoost
# 3829  2024-11-19  AURE3      9.89   10.479733  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 3825  2024-11-12  AURE3      9.96   10.548484  Gradient Boosting
# 3826  2024-11-13  AURE3      9.97   10.430638  Gradient Boosting
# 3827  2024-11-14  AURE3      9.98   10.430638  Gradient Boosting
# 3828  2024-11-18  AURE3      9.80   10.430638  Gradient Boosting
# 3829  2024-11-19  AURE3      9.89   10.517711  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  0.385513  AURE3
# 1                KNN  0.461599  AURE3
# 2                MLP  0.258411  AURE3
# 3      Random Forest  0.301368  AURE3
# 4           AdaBoost  0.403743  AURE3
# 5  Gradient Boosting  0.353069  AURE3
# B3SA3
# 5994  2024-11-12  CMIG3     14.41   14.589365  Decision Tree
# 5995  2024-11-13  CMIG3     14.57   14.140000  Decision Tree
# 5996  2024-11-14  CMIG3     15.53   14.342331  Decision Tree
# 5997  2024-11-18  CMIG3     14.63   14.342331  Decision Tree
# 5998  2024-11-19  CMIG3     14.90   14.342331  Decision Tree
#             date  stock  Adjusted  Prediction Model
# 5994  2024-11-12  CMIG3     14.41   14.170000   KNN
# 5995  2024-11-13  CMIG3     14.57   14.465934   KNN
# 5996  2024-11-14  CMIG3     15.53   14.414066   KNN
# 5997  2024-11-18  CMIG3     14.63   14.340289   KNN
# 5998  2024-11-19  CMIG3     14.90   14.342255   KNN
#             date  stock  Adjusted  Prediction Model
# 5994  2024-11-12  CMIG3     14.41   14.055849   MLP
# 5995  2024-11-13  CMIG3     14.57   14.173886   MLP
# 5996  2024-11-14  CMIG3     15.53   14.815617   MLP
# 5997  2024-11-18  CMIG3     14.63   14.208272   MLP
# 5998  2024-11-19  CMIG3     14.90   14.406559   MLP
#             date  stock  Adjusted  Prediction          Model
# 5994  2024-11-12  CMIG3     14.41   14.540134  Random Forest
# 5995  2024-11-13  CMIG3     14.57   14.160470  Random Forest
# 5996  2024-11-14  CMIG3     15.53   14.340236  Random Forest
# 5997  2024-11-18  CMIG3     14.63   14.439236  Random Forest
# 5998  2024-11-19  CMIG3     14.90   14.405490  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 5994  2024-11-12  CMIG3     14.41   14.297565  AdaBoost
# 5995  2024-11-13  CMIG3     14.57   14.297565  AdaBoost
# 5996  2024-11-14  CMIG3     15.53   14.297565  AdaBoost
# 5997  2024-11-18  CMIG3     14.63   14.297565  AdaBoost
# 5998  2024-11-19  CMIG3     14.90   14.297565  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 5994  2024-11-12  CMIG3     14.41   14.535619  Gradient Boosting
# 5995  2024-11-13  CMIG3     14.57   14.206460  Gradient Boosting
# 5996  2024-11-14  CMIG3     15.53   14.288095  Gradient Boosting
# 5997  2024-11-18  CMIG3     14.63   14.348549  Gradient Boosting
# 5998  2024-11-19  CMIG3     14.90   14.236485  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  4.003459  CMIG3
# 1                KNN  3.999127  CMIG3
# 2                MLP  4.014342  CMIG3
# 3      Random Forest  4.011823  CMIG3
# 4           AdaBoost  3.981412  CMIG3
# 5  Gradient Boosting  3.991689  CMIG3
# CMIG4
#       stock        date    Volume  Adjusted    Future
# 5999  CMIG4  2022-01-03  12606893  4.712060  4.444995
# 6000  CMIG4  2022-01-04   9717669  4.708402  4.573040
# 6001  CMIG4  2022-01-05   9634521  4.558406  4.638891
# 6002  CMIG4  2022-01-06  10608468  4.459629  4.646208
# 6003  CMIG4  2022-01-07  11865490  4.485237  4.657184
#             date  stock  Adjusted  Prediction          Model
# 6717  2024-11-12  CMIG4     11.36        11.4  Decision Tree
# 6718  2024-11-13  CMIG4     11.49        11.4  Decision Tree
# 6719  2024-11-14  CMIG4     12.09        11.4  Decision Tree
# 6720  2024-11-18  CMIG4     11.59        11.4  Decision Tree
# 6721  2024-11-19  CMIG4     11.95        11.4  Decision Tree
#             date  stock  Adjusted  Prediction Model
# 6717  2024-11-12  CMIG4     11.36   11.224270   KNN
# 6718  2024-11-13  CMIG4     11.49   11.209153   KNN
# 6719  2024-11-14  CMIG4     12.09    9.824432   KNN
# 6720  2024-11-18  CMIG4     11.59   10.765746   KNN
# 6721  2024-11-19  CMIG4     11.95   11.214387   KNN
#             date  stock  Adjusted  Prediction Model
# 6717  2024-11-12  CMIG4     11.36   10.828093   MLP
# 6718  2024-11-13  CMIG4     11.49   10.904435   MLP
# 6719  2024-11-14  CMIG4     12.09   11.134246   MLP
# 6720  2024-11-18  CMIG4     11.59   10.943484   MLP
# 6721  2024-11-19  CMIG4     11.95   11.161192   MLP
#             date  stock  Adjusted  Prediction          Model
# 6717  2024-11-12  CMIG4     11.36   11.305483  Random Forest
# 6718  2024-11-13  CMIG4     11.49   11.354876  Random Forest
# 6719  2024-11-14  CMIG4     12.09   11.237749  Random Forest
# 6720  2024-11-18  CMIG4     11.59   11.237749  Random Forest
# 6721  2024-11-19  CMIG4     11.95   11.354876  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 6717  2024-11-12  CMIG4     11.36   11.045993  AdaBoost
# 6718  2024-11-13  CMIG4     11.49   11.043349  AdaBoost
# 6719  2024-11-14  CMIG4     12.09   11.040987  AdaBoost
# 6720  2024-11-18  CMIG4     11.59   11.040987  AdaBoost
# 6721  2024-11-19  CMIG4     11.95   11.043349  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 6717  2024-11-12  CMIG4     11.36   11.275291  Gradient Boosting
# 6718  2024-11-13  CMIG4     11.49   11.244947  Gradient Boosting
# 6719  2024-11-14  CMIG4     12.09   11.139968  Gradient Boosting
# 6720  2024-11-18  CMIG4     11.59   11.232732  Gradient Boosting
# 6721  2024-11-19  CMIG4     11.95   11.244947  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  4.019657  CMIG4
# 1                KNN  4.249105  CMIG4
# 2                MLP  4.213399  CMIG4
# 3      Random Forest  4.060339  CMIG4
# 4           AdaBoost  4.168532  CMIG4
# 5  Gradient Boosting  4.088785  CMIG4
# CPFE3
#       stock        date   Volume   Adjusted     Future
# 6722  CPFE3  2022-01-03  3036200  21.573629  21.298542
# 6723  CPFE3  2022-01-04  2895500  21.506941  21.273533
# 6724  CPFE3  2022-01-05  3249800  21.165165  21.882063
# 6725  CPFE3  2022-01-06  3452500  20.665003  21.548622
# 6726  CPFE3  2022-01-07  2267200  21.123486  21.631981
#             date  stock   Adjusted  Prediction          Model
# 7440  2024-11-12  CPFE3  32.509998   32.642963  Decision Tree
# 7441  2024-11-13  CPFE3  32.430000   32.849998  Decision Tree
# 7442  2024-11-14  CPFE3  32.360001   32.849998  Decision Tree
# 7443  2024-11-18  CPFE3  32.259998   33.049999  Decision Tree
# 7444  2024-11-19  CPFE3  32.500000   33.110001  Decision Tree
#             date  stock   Adjusted  Prediction Model
# 8166  2024-11-18  CPLE3      8.46    8.358132   KNN
# 8167  2024-11-19  CPLE3      8.64    8.474208   KNN
#             date  stock  Adjusted  Prediction Model
# 8163  2024-11-12  CPLE3      8.33    8.347618   MLP
# 8164  2024-11-13  CPLE3      8.35    8.360022   MLP
# 8165  2024-11-14  CPLE3      8.54    8.568267   MLP
# 8166  2024-11-18  CPLE3      8.46    8.475397   MLP
# 8167  2024-11-19  CPLE3      8.64    8.692914   MLP
#             date  stock  Adjusted  Prediction          Model
# 8163  2024-11-12  CPLE3      8.33    8.352171  Random Forest
# 8164  2024-11-13  CPLE3      8.35    8.325312  Random Forest
# 8165  2024-11-14  CPLE3      8.54    8.518930  Random Forest
# 8166  2024-11-18  CPLE3      8.46    8.436316  Random Forest
# 8167  2024-11-19  CPLE3      8.64    8.468039  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 8163  2024-11-12  CPLE3      8.33    8.340904  AdaBoost
# 8164  2024-11-13  CPLE3      8.35    8.340904  AdaBoost
# 8165  2024-11-14  CPLE3      8.54    8.413996  AdaBoost
# 8166  2024-11-18  CPLE3      8.46    8.413996  AdaBoost
# 8167  2024-11-19  CPLE3      8.64    8.548733  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 8163  2024-11-12  CPLE3      8.33    8.365246  Gradient Boosting
# 8164  2024-11-13  CPLE3      8.35    8.321983  Gradient Boosting
# 8165  2024-11-14  CPLE3      8.54    8.478861  Gradient Boosting
# 8166  2024-11-18  CPLE3      8.46    8.472134  Gradient Boosting
# 8167  2024-11-19  CPLE3      8.64    8.404578  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  1.363415  CPLE3
# 1                KNN  1.302049  CPLE3
# 2                MLP  1.328642  CPLE3
# 3      Random Forest  1.308468  CPLE3
# 4           AdaBoost  1.300221  CPLE3
# 5  Gradient Boosting  1.302697  CPLE3
# CPLE6
#       stock        date    Volume  Adjusted    Future
# 8168  CPLE6  2022-01-03  23765272  5.402247  5.150198
# 8169  CPLE6  2022-01-04  10980883  5.343436  5.158599
# 8170  CPLE6  2022-01-05  10478842  5.276223  5.200608
# 8171  CPLE6  2022-01-06  13938313  5.141797  5.234214
# 8172  CPLE6  2022-01-07  10941472  5.124994  5.326632
#             date  stock  Adjusted  Prediction          Model
# 8886  2024-11-12  CPLE6      9.36    9.726615  Decision Tree
# 8887  2024-11-13  CPLE6      9.40    9.618868  Decision Tree
# 8888  2024-11-14  CPLE6      9.59    9.031157  Decision Tree
# 8889  2024-11-18  CPLE6      9.49    9.530711  Decision Tree
# 8890  2024-11-19  CPLE6      9.57    9.481735  Decision Tree
#             date  stock  Adjusted  Prediction Model
# 8886  2024-11-12  CPLE6      9.36    9.271848   KNN
# 8887  2024-11-13  CPLE6      9.40    9.394499   KNN
# 8888  2024-11-14  CPLE6      9.59    9.489928   KNN
# 8889  2024-11-18  CPLE6      9.49    9.719272   KNN
# 8890  2024-11-19  CPLE6      9.57    9.148512   KNN
#             date  stock  Adjusted  Prediction Model
# 8886  2024-11-12  CPLE6      9.36    9.365075   MLP
# 8887  2024-11-13  CPLE6      9.40    9.409658   MLP
# 8888  2024-11-14  CPLE6      9.59    9.575682   MLP
# 8889  2024-11-18  CPLE6      9.49    9.478532   MLP
# 8890  2024-11-19  CPLE6      9.57    9.546595   MLP
#             date  stock  Adjusted  Prediction          Model
# 8886  2024-11-12  CPLE6      9.36    9.616046  Random Forest
# 8887  2024-11-13  CPLE6      9.40    9.378286  Random Forest
# 8888  2024-11-14  CPLE6      9.59    9.547247  Random Forest
# 8889  2024-11-18  CPLE6      9.49    9.509332  Random Forest
# 8890  2024-11-19  CPLE6      9.57    9.557467  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 8886  2024-11-12  CPLE6      9.36    9.305310  AdaBoost
# 8887  2024-11-13  CPLE6      9.40    9.305310  AdaBoost
# 8888  2024-11-14  CPLE6      9.59    9.334636  AdaBoost
# 8889  2024-11-18  CPLE6      9.49    9.305310  AdaBoost
# 8890  2024-11-19  CPLE6      9.57    9.334636  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 8886  2024-11-12  CPLE6      9.36    9.498946  Gradient Boosting
# 8887  2024-11-13  CPLE6      9.40    9.245569  Gradient Boosting
# 8888  2024-11-14  CPLE6      9.59    9.750780  Gradient Boosting
# 8889  2024-11-18  CPLE6      9.49    9.262060  Gradient Boosting
# 8890  2024-11-19  CPLE6      9.57    9.649880  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  3.826025  CPLE6
# 1                KNN  3.856316  CPLE6
# 2                MLP  3.822414  CPLE6
# 3      Random Forest  3.806697  CPLE6
# 4           AdaBoost  3.889051  CPLE6
# 5  Gradient Boosting  3.825372  CPLE6
# CSAN3
#       stock        date   Volume   Adjusted     Future
# 8891  CSAN3  2022-01-03  8988900  19.464180  18.140211
# 8892  CSAN3  2022-01-04  6331300  19.583706  18.903332
# 8893  CSAN3  2022-01-05  8466900  18.609116  19.519346
# 8894  CSAN3  2022-01-06  6832500  18.176987  19.353849
# 8895  CSAN3  2022-01-07  5231700  18.213764  19.510151
#             date  stock  Adjusted  Prediction          Model
# 9609  2024-11-12  CSAN3     11.36   13.016154  Decision Tree
# 9610  2024-11-13  CSAN3     11.43   13.016154  Decision Tree
# 9611  2024-11-14  CSAN3     11.30   13.016154  Decision Tree
# 9612  2024-11-18  CSAN3     11.05   12.310000  Decision Tree
# 9613  2024-11-19  CSAN3     11.00   13.016154  Decision Tree
#             date  stock  Adjusted  Prediction Model
# 9609  2024-11-12  CSAN3     11.36   13.078571   KNN
# 9610  2024-11-13  CSAN3     11.43   12.838572   KNN
# 9611  2024-11-14  CSAN3     11.30   12.994286   KNN
# 9612  2024-11-18  CSAN3     11.05   12.908572   KNN
# 9613  2024-11-19  CSAN3     11.00   13.078571   KNN
#             date  stock  Adjusted  Prediction Model
# 9609  2024-11-12  CSAN3     11.36   11.427131   MLP
# 9610  2024-11-13  CSAN3     11.43   11.505702   MLP
# 9611  2024-11-14  CSAN3     11.30   11.379145   MLP
# 9612  2024-11-18  CSAN3     11.05   11.154912   MLP
# 9613  2024-11-19  CSAN3     11.00   11.085557   MLP
#             date  stock  Adjusted  Prediction          Model
# 9609  2024-11-12  CSAN3     11.36   12.983566  Random Forest
# 9610  2024-11-13  CSAN3     11.43   13.206360  Random Forest
# 9611  2024-11-14  CSAN3     11.30   12.898742  Random Forest
# 9612  2024-11-18  CSAN3     11.05   13.072631  Random Forest
# 9613  2024-11-19  CSAN3     11.00   13.153911  Random Forest
#             date  stock  Adjusted  Prediction     Model
# 9609  2024-11-12  CSAN3     11.36   13.184881  AdaBoost
# 9610  2024-11-13  CSAN3     11.43   13.184881  AdaBoost
# 9611  2024-11-14  CSAN3     11.30   13.184881  AdaBoost
# 9612  2024-11-18  CSAN3     11.05   13.184881  AdaBoost
# 9613  2024-11-19  CSAN3     11.00   13.184881  AdaBoost
#             date  stock  Adjusted  Prediction              Model
# 9609  2024-11-12  CSAN3     11.36   13.170527  Gradient Boosting
# 9610  2024-11-13  CSAN3     11.43   13.170527  Gradient Boosting
# 9611  2024-11-14  CSAN3     11.30   13.170527  Gradient Boosting
# 9612  2024-11-18  CSAN3     11.05   13.170527  Gradient Boosting
# 9613  2024-11-19  CSAN3     11.00   13.198123  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  2.099567  CSAN3
# 1                KNN  2.120468  CSAN3
# 2                MLP  1.036228  CSAN3
# 3      Random Forest  2.118790  CSAN3
# 4           AdaBoost  2.175583  CSAN3
# 5  Gradient Boosting  2.181366  CSAN3
# CSMG3
#       stock        date   Volume  Adjusted    Future
# 9614  CSMG3  2022-01-03  2160900  9.197464  8.698258
# 9615  CSMG3  2022-01-04  2103500  9.189899  8.728516
# 9616  CSMG3  2022-01-05  1350200  9.023499  8.978116
# 9617  CSMG3  2022-01-06  1953900  8.758768  8.970553
# 9618  CSMG3  2022-01-07  1456500  8.766335  9.068882
#              date  stock   Adjusted  Prediction          Model
# 10332  2024-11-12  CSMG3  23.910000   24.639875  Decision Tree
# 10333  2024-11-13  CSMG3  23.590000   22.299999  Decision Tree
# 10334  2024-11-14  CSMG3  24.639999   22.670000  Decision Tree
# 10335  2024-11-18  CSMG3  24.629999   22.670000  Decision Tree
# 10336  2024-11-19  CSMG3  25.040001   24.889999  Decision Tree
#              date  stock   Adjusted  Prediction Model
# 10332  2024-11-12  CSMG3  23.910000   22.790395   KNN
# 10333  2024-11-13  CSMG3  23.590000   24.015274   KNN
# 10334  2024-11-14  CSMG3  24.639999   21.848730   KNN
# 10335  2024-11-18  CSMG3  24.629999   24.906920   KNN
# 10336  2024-11-19  CSMG3  25.040001   22.808278   KNN
#              date  stock   Adjusted  Prediction Model
# 10332  2024-11-12  CSMG3  23.910000   23.167064   MLP
# 10333  2024-11-13  CSMG3  23.590000   23.051680   MLP
# 10334  2024-11-14  CSMG3  24.639999   22.705538   MLP
# 10335  2024-11-18  CSMG3  24.629999   23.813607   MLP
# 10336  2024-11-19  CSMG3  25.040001   24.032770   MLP
#              date  stock   Adjusted  Prediction          Model
# 51543  2024-11-12  VIVA3  24.750000   25.134387   MLP
# 51544  2024-11-13  VIVA3  24.309999   23.927224   MLP
# 51545  2024-11-14  VIVA3  24.000000   24.402092   MLP
# 51546  2024-11-18  VIVA3  23.950001   24.301078   MLP
# 51547  2024-11-19  VIVA3  23.940001   24.339732   MLP
#              date  stock   Adjusted  Prediction          Model
# 51543  2024-11-12  VIVA3  24.750000   25.754874  Random Forest
# 51544  2024-11-13  VIVA3  24.309999   24.285812  Random Forest
# 51545  2024-11-14  VIVA3  24.000000   23.220851  Random Forest
# 51546  2024-11-18  VIVA3  23.950001   24.475021  Random Forest
# 51547  2024-11-19  VIVA3  23.940001   23.445800  Random Forest
#              date  stock   Adjusted  Prediction     Model
# 51543  2024-11-12  VIVA3  24.750000   24.925585  AdaBoost
# 51544  2024-11-13  VIVA3  24.309999   24.523823  AdaBoost
# 51545  2024-11-14  VIVA3  24.000000   24.129083  AdaBoost
# 51546  2024-11-18  VIVA3  23.950001   23.931740  AdaBoost
# 51547  2024-11-19  VIVA3  23.940001   23.931740  AdaBoost
#              date  stock   Adjusted  Prediction              Model
# 51543  2024-11-12  VIVA3  24.750000   25.104725  Gradient Boosting
# 51544  2024-11-13  VIVA3  24.309999   24.009668  Gradient Boosting
# 51545  2024-11-14  VIVA3  24.000000   24.169700  Gradient Boosting
# 51546  2024-11-18  VIVA3  23.950001   24.169700  Gradient Boosting
# 51547  2024-11-19  VIVA3  23.940001   24.128790  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  7.309243  VIVA3
# 1                KNN  7.192463  VIVA3
# 2                MLP  7.312106  VIVA3
# 3      Random Forest  7.268493  VIVA3
# 4           AdaBoost  7.249587  VIVA3
# 5  Gradient Boosting  7.268633  VIVA3
# VLID3
#        stock        date  Volume  Adjusted    Future
# 51548  VLID3  2022-01-03  701500  6.835387  6.501911
# 51549  VLID3  2022-01-04  390000  6.778426  6.746470
# 51550  VLID3  2022-01-05  959500  6.737738  6.738037
# 51551  VLID3  2022-01-06  997200  6.459745  6.712739
# 51552  VLID3  2022-01-07  425300  6.746470  6.670573
#              date  stock   Adjusted  Prediction          Model
# 52266  2024-11-12  VLID3  24.670000   23.311773  Decision Tree
# 52267  2024-11-13  VLID3  25.049999   22.373043  Decision Tree
# 52268  2024-11-14  VLID3  24.510000   22.373043  Decision Tree
# 52269  2024-11-18  VLID3  24.900000   22.979305  Decision Tree
# 52270  2024-11-19  VLID3  24.400000   22.138361  Decision Tree
#              date  stock   Adjusted  Prediction Model
# 52266  2024-11-12  VLID3  24.670000   22.832750   KNN
# 52267  2024-11-13  VLID3  25.049999   22.837484   KNN
# 52268  2024-11-14  VLID3  24.510000   22.803260   KNN
# 52269  2024-11-18  VLID3  24.900000   22.372427   KNN
# 52270  2024-11-19  VLID3  24.400000   21.666960   KNN
#              date  stock   Adjusted  Prediction Model
# 52266  2024-11-12  VLID3  24.670000   23.093236   MLP
# 52267  2024-11-13  VLID3  25.049999   23.269486   MLP
# 52268  2024-11-14  VLID3  24.510000   22.954621   MLP
# 52269  2024-11-18  VLID3  24.900000   23.263217   MLP
# 52270  2024-11-19  VLID3  24.400000   22.714122   MLP
#              date  stock   Adjusted  Prediction          Model
# 52266  2024-11-12  VLID3  24.670000   22.931967  Random Forest
# 52267  2024-11-13  VLID3  25.049999   22.480845  Random Forest
# 52268  2024-11-14  VLID3  24.510000   22.570024  Random Forest
# 52269  2024-11-18  VLID3  24.900000   22.824208  Random Forest
# 52270  2024-11-19  VLID3  24.400000   22.200682  Random Forest
#              date  stock   Adjusted  Prediction     Model
# 52266  2024-11-12  VLID3  24.670000   22.250417  AdaBoost
# 52267  2024-11-13  VLID3  25.049999   22.250417  AdaBoost
# 52268  2024-11-14  VLID3  24.510000   22.250417  AdaBoost
# 52269  2024-11-18  VLID3  24.900000   22.250417  AdaBoost
# 52270  2024-11-19  VLID3  24.400000   22.250417  AdaBoost
#              date  stock   Adjusted  Prediction              Model
# 52266  2024-11-12  VLID3  24.670000   22.630615  Gradient Boosting
# 52267  2024-11-13  VLID3  25.049999   22.723788  Gradient Boosting
# 52268  2024-11-14  VLID3  24.510000   22.382796  Gradient Boosting
# 52269  2024-11-18  VLID3  24.900000   23.094328  Gradient Boosting
# 52270  2024-11-19  VLID3  24.400000   21.837737  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  6.826152  VLID3
# 1                KNN  7.113376  VLID3
# 2                MLP  7.040772  VLID3
# 3      Random Forest  6.791605  VLID3
# 4           AdaBoost  6.705458  VLID3
# 5  Gradient Boosting  6.783586  VLID3
# VULC3
#        stock        date   Volume  Adjusted    Future
# 52271  VULC3  2022-01-03   689793  6.863752  6.234833
# 52272  VULC3  2022-01-04  1162189  6.444474  6.273656
# 52273  VULC3  2022-01-05   547294  6.219305  6.522116
# 52274  VULC3  2022-01-06  1577220  6.328006  6.475532
# 52275  VULC3  2022-01-07   523476  6.382358  6.692934
#              date  stock   Adjusted  Prediction          Model
# 52989  2024-11-12  VULC3  16.045000   16.081181  Decision Tree
# 52990  2024-11-13  VULC3  15.935850   16.081181  Decision Tree
# 52991  2024-11-14  VULC3  15.975541   16.081181  Decision Tree
# 52992  2024-11-18  VULC3  16.045000   16.081181  Decision Tree
# 52993  2024-11-19  VULC3  15.820000   16.081181  Decision Tree
#              date  stock   Adjusted  Prediction Model
# 52989  2024-11-12  VULC3  16.045000   15.950066   KNN
# 52990  2024-11-13  VULC3  15.935850   16.047694   KNN
# 52991  2024-11-14  VULC3  15.975541   16.009720   KNN
# 52992  2024-11-18  VULC3  16.045000   15.955991   KNN
# 52993  2024-11-19  VULC3  15.820000   15.746604   KNN
#              date  stock   Adjusted  Prediction Model
# 52989  2024-11-12  VULC3  16.045000   16.119710   MLP
# 52990  2024-11-13  VULC3  15.935850   16.038929   MLP
# 52991  2024-11-14  VULC3  15.975541   15.983045   MLP
# 52992  2024-11-18  VULC3  16.045000   16.076456   MLP
# 52993  2024-11-19  VULC3  15.820000   15.956079   MLP
#              date  stock   Adjusted  Prediction          Model
# 52989  2024-11-12  VULC3  16.045000   16.273059  Random Forest
# 52990  2024-11-13  VULC3  15.935850   16.436418  Random Forest
# 52991  2024-11-14  VULC3  15.975541   15.680994  Random Forest
# 52992  2024-11-18  VULC3  16.045000   15.716615  Random Forest
# 52993  2024-11-19  VULC3  15.820000   15.707154  Random Forest
#              date  stock   Adjusted  Prediction     Model
# 52989  2024-11-12  VULC3  16.045000   15.914416  AdaBoost
# 52990  2024-11-13  VULC3  15.935850   15.904504  AdaBoost
# 52991  2024-11-14  VULC3  15.975541   15.904504  AdaBoost
# 52992  2024-11-18  VULC3  16.045000   15.914416  AdaBoost
# 52993  2024-11-19  VULC3  15.820000   15.810514  AdaBoost
#              date  stock   Adjusted  Prediction              Model
# 52989  2024-11-12  VULC3  16.045000   15.940844  Gradient Boosting
# 52990  2024-11-13  VULC3  15.935850   15.987606  Gradient Boosting
# 52991  2024-11-14  VULC3  15.975541   16.120615  Gradient Boosting
# 52992  2024-11-18  VULC3  16.045000   15.945339  Gradient Boosting
# 52993  2024-11-19  VULC3  15.820000   15.755917  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  5.407353  VULC3
# 1                KNN  5.463470  VULC3
# 2                MLP  5.414750  VULC3
# 3      Random Forest  5.445878  VULC3
# 4           AdaBoost  5.480914  VULC3
# 5  Gradient Boosting  5.455519  VULC3
# WEGE3
#        stock        date   Volume   Adjusted     Future
# 52994  WEGE3  2022-01-03  5475700  30.455624  27.164665
# 52995  WEGE3  2022-01-04  4485400  30.303438  27.621214
# 52996  WEGE3  2022-01-05  8402200  28.705515  28.743563
# 52997  WEGE3  2022-01-06  6043900  28.696007  27.678284
# 52998  WEGE3  2022-01-07  6155500  27.973137  29.200113
#              date  stock   Adjusted  Prediction          Model
# 53712  2024-11-12  WEGE3  55.419998   54.000000  Decision Tree
# 53713  2024-11-13  WEGE3  54.700001   53.400002  Decision Tree
# 53714  2024-11-14  WEGE3  54.349998   53.400002  Decision Tree
# 53715  2024-11-18  WEGE3  54.000000   53.190076  Decision Tree
# 53716  2024-11-19  WEGE3  54.130001   53.190076  Decision Tree
#              date  stock   Adjusted  Prediction Model
# 53712  2024-11-12  WEGE3  55.419998   53.720080   KNN
# 53713  2024-11-13  WEGE3  54.700001   54.203278   KNN
# 53714  2024-11-14  WEGE3  54.349998   53.784916   KNN
# 53715  2024-11-18  WEGE3  54.000000   53.643959   KNN
# 53716  2024-11-19  WEGE3  54.130001   53.830868   KNN
#              date  stock   Adjusted  Prediction Model
# 53712  2024-11-12  WEGE3  55.419998   56.020972   MLP
# 53713  2024-11-13  WEGE3  54.700001   55.145716   MLP
# 53714  2024-11-14  WEGE3  54.349998   54.920907   MLP
# 53715  2024-11-18  WEGE3  54.000000   54.728521   MLP
# 53716  2024-11-19  WEGE3  54.130001   54.700040   MLP
#              date  stock   Adjusted  Prediction          Model
# 53712  2024-11-12  WEGE3  55.419998   53.577022  Random Forest
# 53713  2024-11-13  WEGE3  54.700001   54.706875  Random Forest
# 53714  2024-11-14  WEGE3  54.349998   53.758279  Random Forest
# 53715  2024-11-18  WEGE3  54.000000   53.035485  Random Forest
# 53716  2024-11-19  WEGE3  54.130001   53.682961  Random Forest
#              date  stock   Adjusted  Prediction     Model
# 53712  2024-11-12  WEGE3  55.419998   53.834687  AdaBoost
# 53713  2024-11-13  WEGE3  54.700001   53.834687  AdaBoost
# 53714  2024-11-14  WEGE3  54.349998   53.834687  AdaBoost
# 53715  2024-11-18  WEGE3  54.000000   53.826193  AdaBoost
# 53716  2024-11-19  WEGE3  54.130001   53.826193  AdaBoost
#              date  stock   Adjusted  Prediction              Model
# 53712  2024-11-12  WEGE3  55.419998   53.975962  Gradient Boosting
# 53713  2024-11-13  WEGE3  54.700001   54.284406  Gradient Boosting
# 53714  2024-11-14  WEGE3  54.349998   53.833143  Gradient Boosting
# 53715  2024-11-18  WEGE3  54.000000   53.392185  Gradient Boosting
# 53716  2024-11-19  WEGE3  54.130001   53.714025  Gradient Boosting
#            Algorithm       RMSE Ticker
# 0      Decision Tree  19.426924  WEGE3
# 1                KNN  19.604876  WEGE3
# 2                MLP  20.081645  WEGE3
# 3      Random Forest  19.549917  WEGE3
# 4           AdaBoost  19.583677  WEGE3
# 5  Gradient Boosting  19.592732  WEGE3
# WIZC3
#        stock        date   Volume  Adjusted    Future
# 53717  WIZC3  2022-01-03  2168100  6.369119  5.928435
# 53718  WIZC3  2022-01-04  2651500  6.127990  5.886862
# 53719  WIZC3  2022-01-05  2390000  5.903491  6.219453
# 53720  WIZC3  2022-01-06  2580600  5.920121  5.828659
# 53721  WIZC3  2022-01-07  1977100  5.936750  5.970009
#              date  stock  Adjusted  Prediction          Model
# 54430  2024-11-05  WIZC3      5.85    5.878495  Decision Tree
# 54431  2024-11-06  WIZC3      5.89    5.975144  Decision Tree
# 54432  2024-11-07  WIZC3      5.85    5.784852  Decision Tree
# 54433  2024-11-08  WIZC3      5.84    5.835207  Decision Tree
# 54434  2024-11-11  WIZC3      5.85    5.784852  Decision Tree
#              date  stock  Adjusted  Prediction Model
# 54430  2024-11-05  WIZC3      5.85    5.828658   KNN
# 54431  2024-11-06  WIZC3      5.89    5.895801   KNN
# 54432  2024-11-07  WIZC3      5.85    5.847143   KNN
# 54433  2024-11-08  WIZC3      5.84    5.857294   KNN
# 54434  2024-11-11  WIZC3      5.85    5.801429   KNN
#              date  stock  Adjusted  Prediction Model
# 54430  2024-11-05  WIZC3      5.85    5.861527   MLP
# 54431  2024-11-06  WIZC3      5.89    5.904815   MLP
# 54432  2024-11-07  WIZC3      5.85    5.877648   MLP
# 54433  2024-11-08  WIZC3      5.84    5.920643   MLP
# 54434  2024-11-11  WIZC3      5.85    5.869184   MLP
#              date  stock  Adjusted  Prediction          Model
# 54430  2024-11-05  WIZC3      5.85    5.844811  Random Forest
# 54431  2024-11-06  WIZC3      5.89    5.871991  Random Forest
# 54432  2024-11-07  WIZC3      5.85    5.813554  Random Forest
# 54433  2024-11-08  WIZC3      5.84    5.903864  Random Forest
# 54434  2024-11-11  WIZC3      5.85    5.825210  Random Forest
#              date  stock  Adjusted  Prediction     Model
# 54430  2024-11-05  WIZC3      5.85    5.893414  AdaBoost
# 54431  2024-11-06  WIZC3      5.89    5.893414  AdaBoost
# 54432  2024-11-07  WIZC3      5.85    5.893414  AdaBoost
# 54433  2024-11-08  WIZC3      5.84    5.893414  AdaBoost
# 54434  2024-11-11  WIZC3      5.85    5.893414  AdaBoost
#              date  stock  Adjusted  Prediction              Model
# 54430  2024-11-05  WIZC3      5.85    5.872264  Gradient Boosting
# 54431  2024-11-06  WIZC3      5.89    5.827081  Gradient Boosting
# 54432  2024-11-07  WIZC3      5.85    5.831873  Gradient Boosting
# 54433  2024-11-08  WIZC3      5.84    5.894102  Gradient Boosting
# 54434  2024-11-11  WIZC3      5.85    5.817804  Gradient Boosting
#            Algorithm      RMSE Ticker
# 0      Decision Tree  0.173988  WIZC3
# 1                KNN  0.122768  WIZC3
# 2                MLP  0.118696  WIZC3
# 3      Random Forest  0.111789  WIZC3
# 4           AdaBoost  0.109611  WIZC3
# 5  Gradient Boosting  0.156598  WIZC3

# %%
print(results)
print('\n\n',predictions)
# Out:
# [           Algorithm      RMSE Ticker
# 0      Decision Tree  2.923042  ABEV3
# 1                KNN  2.988892  ABEV3
# 2                MLP  2.951994  ABEV3
# 3      Random Forest  2.934138  ABEV3
# 4           AdaBoost  2.947377  ABEV3
# 5  Gradient Boosting  2.941046  ABEV3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.292476  AGRO3
# 1                KNN  1.223127  AGRO3
# 2                MLP  1.145003  AGRO3
# 3      Random Forest  1.232401  AGRO3
# 4           AdaBoost  1.207395  AGRO3
# 5  Gradient Boosting  1.199997  AGRO3,            Algorithm         RMSE Ticker
# 0      Decision Tree  1158.702838  ALOS3
# 1                KNN  1158.650746  ALOS3
# 2                MLP  1158.462376  ALOS3
# 3      Random Forest  1158.651560  ALOS3
# 4           AdaBoost  1158.643244  ALOS3
# 5  Gradient Boosting  1158.631585  ALOS3,            Algorithm       RMSE Ticker
# 0      Decision Tree  11.828714  AMER3
# 1                KNN  27.261078  AMER3
# 2                MLP  31.037031  AMER3
# 3      Random Forest   9.926028  AMER3
# 4           AdaBoost  33.029173  AMER3
# 5  Gradient Boosting  10.084550  AMER3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.925003  ARML3
# 1                KNN  1.917945  ARML3
# 2                MLP  1.939526  ARML3
# 3      Random Forest  1.918503  ARML3
# 4           AdaBoost  1.904222  ARML3
# 5  Gradient Boosting  1.884709  ARML3,            Algorithm      RMSE Ticker
# 0      Decision Tree  0.385513  AURE3
# 1                KNN  0.461599  AURE3
# 2                MLP  0.258411  AURE3
# 3      Random Forest  0.301368  AURE3
# 4           AdaBoost  0.403743  AURE3
# 5  Gradient Boosting  0.353069  AURE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  7.676554  B3SA3
# 1                KNN  7.495474  B3SA3
# 2                MLP  7.579942  B3SA3
# 3      Random Forest  7.601652  B3SA3
# 4           AdaBoost  7.523552  B3SA3
# 5  Gradient Boosting  7.521085  B3SA3,            Algorithm      RMSE Ticker
# 0      Decision Tree  3.415735  BLAU3
# 1                KNN  3.440455  BLAU3
# 2                MLP  3.447746  BLAU3
# 3      Random Forest  3.332143  BLAU3
# 4           AdaBoost  3.450048  BLAU3
# 5  Gradient Boosting  3.297881  BLAU3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.003459  CMIG3
# 1                KNN  3.999127  CMIG3
# 2                MLP  4.014342  CMIG3
# 3      Random Forest  4.011823  CMIG3
# 4           AdaBoost  3.981412  CMIG3
# 5  Gradient Boosting  3.991689  CMIG3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.019657  CMIG4
# 1                KNN  4.249105  CMIG4
# 2                MLP  4.213399  CMIG4
# 3      Random Forest  4.060339  CMIG4
# 4           AdaBoost  4.168532  CMIG4
# 5  Gradient Boosting  4.088785  CMIG4,            Algorithm       RMSE Ticker
# 0      Decision Tree  11.459617  CPFE3
# 1                KNN  11.464444  CPFE3
# 2                MLP  11.345906  CPFE3
# 3      Random Forest  11.407654  CPFE3
# 4           AdaBoost  11.364442  CPFE3
# 5  Gradient Boosting  11.374950  CPFE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.363415  CPLE3
# 1                KNN  1.302049  CPLE3
# 2                MLP  1.328642  CPLE3
# 3      Random Forest  1.308468  CPLE3
# 4           AdaBoost  1.300221  CPLE3
# 5  Gradient Boosting  1.302697  CPLE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  3.826025  CPLE6
# 1                KNN  3.856316  CPLE6
# 2                MLP  3.822414  CPLE6
# 3      Random Forest  3.806697  CPLE6
# 4           AdaBoost  3.889051  CPLE6
# 5  Gradient Boosting  3.825372  CPLE6,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.099567  CSAN3
# 1                KNN  2.120468  CSAN3
# 2                MLP  1.036228  CSAN3
# 3      Random Forest  2.118790  CSAN3
# 4           AdaBoost  2.175583  CSAN3
# 5  Gradient Boosting  2.181366  CSAN3,            Algorithm      RMSE Ticker
# 0      Decision Tree  7.575107  CSMG3
# 1                KNN  7.508585  CSMG3
# 2                MLP  7.542000  CSMG3
# 3      Random Forest  7.760636  CSMG3
# 4           AdaBoost  7.582476  CSMG3
# 5  Gradient Boosting  7.856999  CSMG3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.368157  CURY3
# 1                KNN  4.470526  CURY3
# 2                MLP  4.264771  CURY3
# 3      Random Forest  4.274993  CURY3
# 4           AdaBoost  4.195602  CURY3
# 5  Gradient Boosting  4.258577  CURY3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.848957  CYRE3
# 1                KNN  4.820409  CYRE3
# 2                MLP  4.908644  CYRE3
# 3      Random Forest  4.902367  CYRE3
# 4           AdaBoost  4.905997  CYRE3
# 5  Gradient Boosting  4.966055  CYRE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.386971  DIRR3
# 1                KNN  0.945624  DIRR3
# 2                MLP  0.649467  DIRR3
# 3      Random Forest  0.857483  DIRR3
# 4           AdaBoost  0.773010  DIRR3
# 5  Gradient Boosting  0.719589  DIRR3,            Algorithm      RMSE Ticker
# 0      Decision Tree  3.343104  ELET3
# 1                KNN  3.469464  ELET3
# 2                MLP  3.472629  ELET3
# 3      Random Forest  3.353437  ELET3
# 4           AdaBoost  3.474691  ELET3
# 5  Gradient Boosting  3.403442  ELET3,            Algorithm       RMSE Ticker
# 0      Decision Tree  12.564567  ELET6
# 1                KNN  12.684555  ELET6
# 2                MLP  12.621237  ELET6
# 3      Random Forest  12.707855  ELET6
# 4           AdaBoost  12.440951  ELET6
# 5  Gradient Boosting  12.591499  ELET6,            Algorithm      RMSE Ticker
# 0      Decision Tree  5.772167  ELMD3
# 1                KNN  5.975513  ELMD3
# 2                MLP  6.141896  ELMD3
# 3      Random Forest  5.788362  ELMD3
# 4           AdaBoost  5.777498  ELMD3
# 5  Gradient Boosting  5.731226  ELMD3,            Algorithm      RMSE Ticker
# 0      Decision Tree  9.800524  ENEV3
# 1                KNN  9.784411  ENEV3
# 2                MLP  9.783911  ENEV3
# 3      Random Forest  9.817199  ENEV3
# 4           AdaBoost  9.776992  ENEV3
# 5  Gradient Boosting  9.785809  ENEV3,            Algorithm       RMSE  Ticker
# 0      Decision Tree  14.808431  ENGI11
# 1                KNN  14.954794  ENGI11
# 2                MLP  15.008994  ENGI11
# 3      Random Forest  14.878596  ENGI11
# 4           AdaBoost  14.768914  ENGI11
# 5  Gradient Boosting  14.970486  ENGI11,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.372658  EVEN3
# 1                KNN  4.374470  EVEN3
# 2                MLP  4.319480  EVEN3
# 3      Random Forest  4.354967  EVEN3
# 4           AdaBoost  4.272064  EVEN3
# 5  Gradient Boosting  4.345759  EVEN3,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.066848  EZTC3
# 1                KNN  1.655866  EZTC3
# 2                MLP  1.817167  EZTC3
# 3      Random Forest  1.923091  EZTC3
# 4           AdaBoost  1.827919  EZTC3
# 5  Gradient Boosting  1.842934  EZTC3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.146914  FESA4
# 1                KNN  1.193778  FESA4
# 2                MLP  1.154317  FESA4
# 3      Random Forest  1.169362  FESA4
# 4           AdaBoost  1.240019  FESA4
# 5  Gradient Boosting  1.206609  FESA4,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.816182  FIQE3
# 1                KNN  4.866666  FIQE3
# 2                MLP  4.885491  FIQE3
# 3      Random Forest  4.862208  FIQE3
# 4           AdaBoost  4.888589  FIQE3
# 5  Gradient Boosting  4.882610  FIQE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.760808  GFSA3
# 1                KNN  1.965010  GFSA3
# 2                MLP  1.961940  GFSA3
# 3      Random Forest  1.763415  GFSA3
# 4           AdaBoost  1.729175  GFSA3
# 5  Gradient Boosting  1.703941  GFSA3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.052096  GRND3
# 1                KNN  0.965233  GRND3
# 2                MLP  0.916282  GRND3
# 3      Random Forest  0.986781  GRND3
# 4           AdaBoost  0.973549  GRND3
# 5  Gradient Boosting  0.954094  GRND3,            Algorithm      RMSE Ticker
# 0      Decision Tree  8.315489  HBRE3
# 1                KNN  8.294079  HBRE3
# 2                MLP  8.381199  HBRE3
# 3      Random Forest  8.333030  HBRE3
# 4           AdaBoost  8.387633  HBRE3
# 5  Gradient Boosting  8.364560  HBRE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  5.645401  HYPE3
# 1                KNN  7.513209  HYPE3
# 2                MLP  6.707567  HYPE3
# 3      Random Forest  5.591542  HYPE3
# 4           AdaBoost  6.233316  HYPE3
# 5  Gradient Boosting  5.748096  HYPE3,            Algorithm      RMSE  Ticker
# 0      Decision Tree  2.246964  IGTI11
# 1                KNN  1.663498  IGTI11
# 2                MLP  1.497725  IGTI11
# 3      Random Forest  1.781320  IGTI11
# 4           AdaBoost  1.657026  IGTI11
# 5  Gradient Boosting  1.623976  IGTI11,            Algorithm      RMSE Ticker
# 0      Decision Tree  5.428045  INTB3
# 1                KNN  5.201959  INTB3
# 2                MLP  4.170437  INTB3
# 3      Random Forest  5.104720  INTB3
# 4           AdaBoost  5.362535  INTB3
# 5  Gradient Boosting  5.119585  INTB3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.697427  ITSA3
# 1                KNN  1.624714  ITSA3
# 2                MLP  1.633182  ITSA3
# 3      Random Forest  1.631921  ITSA3
# 4           AdaBoost  1.630866  ITSA3
# 5  Gradient Boosting  1.671418  ITSA3,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.672387  ITSA4
# 1                KNN  2.674432  ITSA4
# 2                MLP  2.639601  ITSA4
# 3      Random Forest  2.696857  ITSA4
# 4           AdaBoost  2.662613  ITSA4
# 5  Gradient Boosting  2.662330  ITSA4,            Algorithm      RMSE Ticker
# 0      Decision Tree  0.352057  JHSF3
# 1                KNN  0.253659  JHSF3
# 2                MLP  0.204684  JHSF3
# 3      Random Forest  0.257556  JHSF3
# 4           AdaBoost  0.215785  JHSF3
# 5  Gradient Boosting  0.242188  JHSF3,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.676564  KEPL3
# 1                KNN  2.633764  KEPL3
# 2                MLP  2.654164  KEPL3
# 3      Random Forest  2.628742  KEPL3
# 4           AdaBoost  2.608030  KEPL3
# 5  Gradient Boosting  2.649865  KEPL3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.202272  LAVV3
# 1                KNN  4.282210  LAVV3
# 2                MLP  4.326868  LAVV3
# 3      Random Forest  4.245831  LAVV3
# 4           AdaBoost  4.298980  LAVV3
# 5  Gradient Boosting  4.232365  LAVV3,            Algorithm      RMSE Ticker
# 0      Decision Tree  3.894592  LEVE3
# 1                KNN  3.914676  LEVE3
# 2                MLP  3.189981  LEVE3
# 3      Random Forest  3.858552  LEVE3
# 4           AdaBoost  4.314976  LEVE3
# 5  Gradient Boosting  3.753277  LEVE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  7.386541  LOGG3
# 1                KNN  7.314910  LOGG3
# 2                MLP  7.224202  LOGG3
# 3      Random Forest  7.355694  LOGG3
# 4           AdaBoost  7.352771  LOGG3
# 5  Gradient Boosting  7.355106  LOGG3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.704718  MDNE3
# 1                KNN  4.776828  MDNE3
# 2                MLP  4.828071  MDNE3
# 3      Random Forest  4.714451  MDNE3
# 4           AdaBoost  4.636222  MDNE3
# 5  Gradient Boosting  4.730611  MDNE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  0.626153  MELK3
# 1                KNN  0.598198  MELK3
# 2                MLP  0.567765  MELK3
# 3      Random Forest  0.595617  MELK3
# 4           AdaBoost  0.575839  MELK3
# 5  Gradient Boosting  0.583846  MELK3,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.160888  MILS3
# 1                KNN  2.146138  MILS3
# 2                MLP  2.113746  MILS3
# 3      Random Forest  2.127419  MILS3
# 4           AdaBoost  2.166073  MILS3
# 5  Gradient Boosting  2.115089  MILS3,            Algorithm      RMSE Ticker
# 0      Decision Tree  6.651592  MULT3
# 1                KNN  6.377547  MULT3
# 2                MLP  6.410253  MULT3
# 3      Random Forest  6.435096  MULT3
# 4           AdaBoost  6.439796  MULT3
# 5  Gradient Boosting  6.462537  MULT3,            Algorithm      RMSE Ticker
# 0      Decision Tree  5.348284  ODPV3
# 1                KNN  5.311052  ODPV3
# 2                MLP  5.344331  ODPV3
# 3      Random Forest  5.268730  ODPV3
# 4           AdaBoost  5.273498  ODPV3
# 5  Gradient Boosting  5.302445  ODPV3,            Algorithm       RMSE Ticker
# 0      Decision Tree  13.227051  ORVR3
# 1                KNN  13.164780  ORVR3
# 2                MLP  13.187131  ORVR3
# 3      Random Forest  13.396456  ORVR3
# 4           AdaBoost  13.145044  ORVR3
# 5  Gradient Boosting  13.259097  ORVR3,            Algorithm       RMSE Ticker
# 0      Decision Tree  11.514826  PETR3
# 1                KNN  11.464306  PETR3
# 2                MLP  11.269235  PETR3
# 3      Random Forest  11.462578  PETR3
# 4           AdaBoost  11.482134  PETR3
# 5  Gradient Boosting  11.397232  PETR3,            Algorithm       RMSE Ticker
# 0      Decision Tree  14.150703  PETR4
# 1                KNN  14.202752  PETR4
# 2                MLP  13.976618  PETR4
# 3      Random Forest  14.322635  PETR4
# 4           AdaBoost  14.205362  PETR4
# 5  Gradient Boosting  14.338614  PETR4,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.069485  PLPL3
# 1                KNN  4.224798  PLPL3
# 2                MLP  4.367937  PLPL3
# 3      Random Forest  4.325361  PLPL3
# 4           AdaBoost  4.493716  PLPL3
# 5  Gradient Boosting  4.443241  PLPL3,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.555417  POMO3
# 1                KNN  1.557826  POMO3
# 2                MLP  1.932890  POMO3
# 3      Random Forest  1.569295  POMO3
# 4           AdaBoost  1.571900  POMO3
# 5  Gradient Boosting  1.561972  POMO3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.872949  POMO4
# 1                KNN  4.920905  POMO4
# 2                MLP  4.439887  POMO4
# 3      Random Forest  4.798003  POMO4
# 4           AdaBoost  4.899795  POMO4
# 5  Gradient Boosting  4.837423  POMO4,            Algorithm       RMSE Ticker
# 0      Decision Tree  11.509765  PRIO3
# 1                KNN  11.434791  PRIO3
# 2                MLP  11.205296  PRIO3
# 3      Random Forest  11.465292  PRIO3
# 4           AdaBoost  11.192232  PRIO3
# 5  Gradient Boosting  11.614439  PRIO3,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.757354  RECV3
# 1                KNN  2.738615  RECV3
# 2                MLP  2.681057  RECV3
# 3      Random Forest  2.700346  RECV3
# 4           AdaBoost  2.549231  RECV3
# 5  Gradient Boosting  2.609842  RECV3,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.038418  ROMI3
# 1                KNN  2.111943  ROMI3
# 2                MLP  2.182295  ROMI3
# 3      Random Forest  2.137339  ROMI3
# 4           AdaBoost  2.074205  ROMI3
# 5  Gradient Boosting  2.191771  ROMI3,            Algorithm      RMSE  Ticker
# 0      Decision Tree  9.458592  SAPR11
# 1                KNN  9.658755  SAPR11
# 2                MLP  9.513592  SAPR11
# 3      Random Forest  9.485292  SAPR11
# 4           AdaBoost  9.561059  SAPR11
# 5  Gradient Boosting  9.465344  SAPR11,            Algorithm       RMSE Ticker
# 0      Decision Tree  12.202054  SAPR4
# 1                KNN  12.207104  SAPR4
# 2                MLP  12.218811  SAPR4
# 3      Random Forest  12.190940  SAPR4
# 4           AdaBoost  12.202872  SAPR4
# 5  Gradient Boosting  12.205832  SAPR4,            Algorithm       RMSE Ticker
# 0      Decision Tree  37.771369  SBSP3
# 1                KNN  37.544437  SBSP3
# 2                MLP  37.837661  SBSP3
# 3      Random Forest  37.689453  SBSP3
# 4           AdaBoost  37.641747  SBSP3
# 5  Gradient Boosting  37.557953  SBSP3,            Algorithm      RMSE Ticker
# 0      Decision Tree  3.624120  SHUL4
# 1                KNN  3.602052  SHUL4
# 2                MLP  3.643299  SHUL4
# 3      Random Forest  3.594754  SHUL4
# 4           AdaBoost  3.575732  SHUL4
# 5  Gradient Boosting  3.611137  SHUL4,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.468546  SMFT3
# 1                KNN  4.227213  SMFT3
# 2                MLP  4.257329  SMFT3
# 3      Random Forest  4.230033  SMFT3
# 4           AdaBoost  4.200576  SMFT3
# 5  Gradient Boosting  4.119620  SMFT3,            Algorithm      RMSE Ticker
# 0      Decision Tree  4.654773  SMTO3
# 1                KNN  4.922536  SMTO3
# 2                MLP  4.756554  SMTO3
# 3      Random Forest  4.835685  SMTO3
# 4           AdaBoost  4.547294  SMTO3
# 5  Gradient Boosting  4.827067  SMTO3,            Algorithm      RMSE Ticker
# 0      Decision Tree  3.190432  SOJA3
# 1                KNN  3.266533  SOJA3
# 2                MLP  3.213023  SOJA3
# 3      Random Forest  3.180021  SOJA3
# 4           AdaBoost  3.213704  SOJA3
# 5  Gradient Boosting  3.176978  SOJA3,            Algorithm      RMSE Ticker
# 0      Decision Tree  3.264266  STBP3
# 1                KNN  2.975709  STBP3
# 2                MLP  3.162900  STBP3
# 3      Random Forest  3.231623  STBP3
# 4           AdaBoost  3.052434  STBP3
# 5  Gradient Boosting  3.161793  STBP3,            Algorithm      RMSE Ticker
# 0      Decision Tree  8.289848  SYNE3
# 1                KNN  8.392701  SYNE3
# 2                MLP  8.259788  SYNE3
# 3      Random Forest  8.308347  SYNE3
# 4           AdaBoost  8.376168  SYNE3
# 5  Gradient Boosting  8.294955  SYNE3,            Algorithm       RMSE  Ticker
# 0      Decision Tree   9.954889  TAEE11
# 1                KNN  10.019765  TAEE11
# 2                MLP  10.024262  TAEE11
# 3      Random Forest  10.056637  TAEE11
# 4           AdaBoost  10.058993  TAEE11
# 5  Gradient Boosting   9.956175  TAEE11,            Algorithm      RMSE Ticker
# 0      Decision Tree  0.364722  TAEE4
# 1                KNN  0.365678  TAEE4
# 2                MLP  0.347042  TAEE4
# 3      Random Forest  0.347318  TAEE4
# 4           AdaBoost  0.346428  TAEE4
# 5  Gradient Boosting  0.338312  TAEE4,            Algorithm      RMSE Ticker
# 0      Decision Tree  1.026566  TFCO4
# 1                KNN  0.611145  TFCO4
# 2                MLP  0.737664  TFCO4
# 3      Random Forest  0.721743  TFCO4
# 4           AdaBoost  0.665710  TFCO4
# 5  Gradient Boosting  0.644844  TFCO4,            Algorithm      RMSE Ticker
# 0      Decision Tree  2.817896  TGMA3
# 1                KNN  3.651204  TGMA3
# 2                MLP  2.935226  TGMA3
# 3      Random Forest  3.010599  TGMA3
# 4           AdaBoost  3.804460  TGMA3
# 5  Gradient Boosting  3.160627  TGMA3,            Algorithm       RMSE Ticker
# 0      Decision Tree  10.107555  TOTS3
# 1                KNN  10.275356  TOTS3
# 2                MLP  10.333230  TOTS3
# 3      Random Forest  10.210965  TOTS3
# 4           AdaBoost  10.279181  TOTS3
# 5  Gradient Boosting  10.243226  TOTS3,            Algorithm      RMSE Ticker
# 0      Decision Tree  6.286955  TRIS3
# 1                KNN  6.411651  TRIS3
# 2                MLP  6.324220  TRIS3
# 3      Random Forest  6.377379  TRIS3
# 4           AdaBoost  6.427876  TRIS3
# 5  Gradient Boosting  6.395134  TRIS3,            Algorithm       RMSE Ticker
# 0      Decision Tree  15.764813  TRPL4
# 1                KNN  15.735834  TRPL4
# 2                MLP  15.831441  TRPL4
# 3      Random Forest  15.623266  TRPL4
# 4           AdaBoost  15.594197  TRPL4
# 5  Gradient Boosting  15.692228  TRPL4,            Algorithm       RMSE Ticker
# 0      Decision Tree  15.433814  VALE3
# 1                KNN  15.412362  VALE3
# 2                MLP  15.094484  VALE3
# 3      Random Forest  15.481784  VALE3
# 4           AdaBoost  15.254371  VALE3
# 5  Gradient Boosting  15.292840  VALE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  7.309243  VIVA3
# 1                KNN  7.192463  VIVA3
# 2                MLP  7.312106  VIVA3
# 3      Random Forest  7.268493  VIVA3
# 4           AdaBoost  7.249587  VIVA3
# 5  Gradient Boosting  7.268633  VIVA3,            Algorithm      RMSE Ticker
# 0      Decision Tree  6.826152  VLID3
# 1                KNN  7.113376  VLID3
# 2                MLP  7.040772  VLID3
# 3      Random Forest  6.791605  VLID3
# 4           AdaBoost  6.705458  VLID3
# 5  Gradient Boosting  6.783586  VLID3,            Algorithm      RMSE Ticker
# 0      Decision Tree  5.407353  VULC3
# 1                KNN  5.463470  VULC3
# 2                MLP  5.414750  VULC3
# 3      Random Forest  5.445878  VULC3
# 4           AdaBoost  5.480914  VULC3
# 5  Gradient Boosting  5.455519  VULC3,            Algorithm       RMSE Ticker
# 0      Decision Tree  19.426924  WEGE3
# 1                KNN  19.604876  WEGE3
# 2                MLP  20.081645  WEGE3
# 3      Random Forest  19.549917  WEGE3
# 4           AdaBoost  19.583677  WEGE3
# 5  Gradient Boosting  19.592732  WEGE3,            Algorithm      RMSE Ticker
# 0      Decision Tree  0.173988  WIZC3
# 1                KNN  0.122768  WIZC3
# 2                MLP  0.118696  WIZC3
# 3      Random Forest  0.111789  WIZC3
# 4           AdaBoost  0.109611  WIZC3
# 5  Gradient Boosting  0.156598  WIZC3]
#
#
#               date  stock  Adjusted  Prediction              Model
# 693    2024-10-08  ABEV3     13.08   12.922303      Decision Tree
# 694    2024-10-09  ABEV3     13.08   12.922303      Decision Tree
# 695    2024-10-10  ABEV3     13.11   13.284205      Decision Tree
# 696    2024-10-11  ABEV3     12.88   12.922303      Decision Tree
# 697    2024-10-14  ABEV3     12.92   12.870000      Decision Tree
# ...           ...    ...       ...         ...                ...
# 54430  2024-11-05  WIZC3      5.85    5.872264  Gradient Boosting
# 54431  2024-11-06  WIZC3      5.89    5.827081  Gradient Boosting
# 54432  2024-11-07  WIZC3      5.85    5.831873  Gradient Boosting
# 54433  2024-11-08  WIZC3      5.84    5.894102  Gradient Boosting
# 54434  2024-11-11  WIZC3      5.85    5.817804  Gradient Boosting
#
# [13680 rows x 5 columns]

# %%
# Concatenate all results into a single DataFrame
final_results = pd.concat(results, ignore_index=True)

# Save the results to a CSV file
final_results.to_csv(path_or_buf='models_results/model_results.csv', index=False)
predictions.to_csv(path_or_buf='models_results/predictions.csv', index=False)

print("Results saved to model_results.csv, and predictions.csv")
# Out:
# Results saved to model_results.csv, and predictions.csv
# "\n# Treinar e prever o resultado para cada ticker\nfor ticker in ticker_train_test_data:\n    train_data = ticker_train_test_data[ticker]['train']\n    test_data = ticker_train_test_data[ticker]['test']\n    \n    if not test_data.empty:\n        # Treinar o melhor modelo\n        best_model = algorithms[final_results.loc[final_results['RMSE'].idxmin(), 'Algorithm']]\n        best_model.fit(train_data[['log_return']], train_data['result'])\n\n        # Prever o resultado\n        y_pred = best_model.predict(test_data[['log_return']])\n        test_data['predicted_result'] = y_pred\n\n        # Plotar o resultado\n        plt.figure(figsize=(10, 5))\n        plt.plot(test_data['Date'], test_data['result'], label='Real')\n        plt.plot(test_data['Date'], test_data['predicted_result'], label='Predicted')\n        plt.title(f'{ticker} - Result Prediction')\n        plt.legend()\n\n        plt.show()\n\n        # Salvar o modelo\n        model_name = f'{ticker}_model.pkl'\n        joblib.dump(best_model, model_name)\n\n        print(f'Model saved as {model_name}')\n\n\n## prophet, ARIMA, LSTM, GRU, Transformer\n#grid search for hyperparameters\n#GridSearchCV\n#cross validation\n\n"
